# %%
# Out:
# <KeysViewHDF5 ['list_classes', 'train_set_x', 'train_set_y']>
# <HDF5 dataset "train_set_x": shape (209, 64, 64, 3), type "|u1">
# <HDF5 dataset "train_set_y": shape (209,), type "<i8">
# <HDF5 dataset "list_classes": shape (2,), type "|S7">

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
# %matplotlib inline


train_dataset = h5py.File('/Users/yeji_kim/Desktop/Ams595/homework/homework3/train_catvnoncat.h5', "r") # change the path
test_dataset = h5py.File('/Users/yeji_kim/Desktop/Ams595/homework/homework3/test_catvnoncat.h5', "r")   # change the path


train_X = np.array(train_dataset["train_set_x"][:])
train_Y = np.array(train_dataset["train_set_y"][:])
test_X = np.array(test_dataset["test_set_x"][:]) #  test set features
test_Y = np.array(test_dataset["test_set_y"][:]) #  test set labels
classes = np.array(test_dataset["list_classes"][:])

train_Y = train_Y.reshape((1, train_Y.shape[0]))
test_Y  = test_Y.reshape((1, test_Y.shape[0]))



# the indices of images that we want to look at
indices = [57, 58, 59, 60]

# create figure
fig = plt.figure(figsize=(10, 7))



# setting values to rows and column variables
rows = 2
columns = 2

for i in indices:
  fig.add_subplot(rows, columns, i - 56) # i - 56 is the subplot indices, 1,2,3,4
  plt.imshow(train_X[i])
  plt.axis('off')
  plt.title("y = " + str(train_Y[0, i]) + ", it's a '" + classes[np.squeeze(train_Y[:, i])].decode("utf-8") +  "' picture.")
   



# the indices of images that we want to look at
indices = [15, 16, 17, 18]

# create figure
fig = plt.figure(figsize=(10, 7))

# setting values to rows and column variables
rows = 2
columns = 2

for i in indices:
  fig.add_subplot(rows, columns, i - 14) # i - 54 is the subplot indices, 1,2,3,4
  plt.imshow(test_X[i])
  plt.axis('off')
  plt.title("y = " + str(test_Y[0, i]) + ", it's a '" + classes[np.squeeze(test_Y[:, i])].decode("utf-8") +  "' picture.")
    


    
    
    
train_X_flat = (train_X.reshape(train_X.shape[0], -1)/255).T  # flatten the image to have a vector, normalize to prevent the calculations from exploding
print(train_X_flat.shape)
test_X_flat = (test_X.reshape(test_X.shape[0], -1)/255).T






 ###Helper function
def sigmoid(z):
    """
    Compute the sigmoid of z

    Arguments:
    z -- A scalar or numpy array of any size.

    Return: sigmoid(z)
    """
    return 1/(1+np.exp(-z))





def propagate(w, b, X, Y):
   

    m = X.shape[1]

    # FORWARD PROPAGATION (FROM X TO COST)
    A = sigmoid(np.dot(w.T,X) + b)
    cost = np.sum(((- np.log(A))*Y + (-np.log(1-A))*(1-Y)))/m  # compute cost

    # BACKWARD PROPAGATION (TO FIND GRAD)
    dw = (np.dot(X,(A-Y).T))/m
    db = (np.sum(A-Y))/m

    cost = np.squeeze(cost)

    return dw, db, cost




##Training

X = train_X_flat
Y = train_Y
dim = train_X_flat.shape[0]
w = np.zeros((dim,1)) # initialize w, shape (dim, 1)
b = 0 # initialize b, scalar
num_iterations = 10000
learning_rate = 0.006
record_cost = 50  # print out the cost every 50 iterations
costs = []

for i in range(num_iterations):
    dw, db, cost = propagate(w, b, X, Y)


    # gradient descent
    w = w - (learning_rate*dw)
    b = b - (learning_rate*db)

    # Record the costs
    if i % record_cost == 0:
        costs.append(cost)
        print (f"Cost after iteration {i} is: {cost}")

scipy.io.savemat("weights.mat", {"weights":w})
scipy.io.savemat("biases.mat", {"biases":b})





##Results

w = scipy.io.loadmat('weights.mat')["weights"]
b = scipy.io.loadmat('biases.mat')["biases"]

A = sigmoid(np.dot(w.T,test_X_flat) + b)
Y_predict_test = (A >= 0.5) * 1.0
Y_predict_train = sigmoid(np.dot(w.T,X) + b)

print(f"train accuracy: {(100 - np.mean(np.abs(Y_predict_train - train_Y)) * 100):2f}")
print(f"test accuracy: {(100 - np.mean(np.abs(Y_predict_test - test_Y)) * 100):2f}")
# Out:
# (12288, 209)
# Cost after iteration 0 is: 0.6931471805599453
# Cost after iteration 50 is: 0.7281013187730967
# Cost after iteration 100 is: 0.6498112732446271
# Cost after iteration 150 is: 0.5919060823227434
# Cost after iteration 200 is: 0.5383118237783534
# Cost after iteration 250 is: 0.4875820528641597
# Cost after iteration 300 is: 0.439261694788975
# Cost after iteration 350 is: 0.3932376486927422
# Cost after iteration 400 is: 0.3498247654306744
# Cost after iteration 450 is: 0.3102483733092726
# Cost after iteration 500 is: 0.2784984357971255
# Cost after iteration 550 is: 0.26060102377338373
# Cost after iteration 600 is: 0.24976400229871917
# Cost after iteration 650 is: 0.240093693258189
# Cost after iteration 700 is: 0.23117767283922816
# Cost after iteration 750 is: 0.2229155289076536
# Cost after iteration 800 is: 0.21522905139235474
# Cost after iteration 850 is: 0.2080545572409308
# Cost after iteration 900 is: 0.20133887003959525
# Cost after iteration 950 is: 0.19503682036924933
# Cost after iteration 1000 is: 0.189109561530962
# Cost after iteration 1050 is: 0.18352336452191584
# Cost after iteration 1100 is: 0.17824871723940577
# Cost after iteration 1150 is: 0.1732596293091416
# Cost after iteration 1200 is: 0.16853308291181374
# Cost after iteration 1250 is: 0.16404859125558635
# Cost after iteration 1300 is: 0.15978783871749244
# Cost after iteration 1350 is: 0.15573438430878062
# Cost after iteration 1400 is: 0.15187341507476673
# Cost after iteration 1450 is: 0.14819153940118582
# Cost after iteration 1500 is: 0.14467661256301045
# Cost after iteration 1550 is: 0.1413175885635718
# Cost after iteration 1600 is: 0.13810439358104692
# Cost after iteration 1650 is: 0.13502781729840593
# Cost after iteration 1700 is: 0.13207941912877474
# Cost after iteration 1750 is: 0.12925144691991955
# Cost after iteration 1800 is: 0.12653676617044218
# Cost after iteration 1850 is: 0.12392879814580544
# Cost after iteration 1900 is: 0.12142146556603164
# Cost after iteration 1950 is: 0.1190091447648464
# Cost after iteration 2000 is: 0.11668662340424088
# Cost after iteration 2050 is: 0.11444906297809695
# Cost after iteration 2100 is: 0.11229196546076611
# Cost after iteration 2150 is: 0.11021114355681104
# Cost after iteration 2200 is: 0.10820269409083334
# Cost after iteration 2250 is: 0.10626297414481255
# Cost after iteration 2300 is: 0.10438857960736009
# Cost after iteration 2350 is: 0.10257632584689318
# Cost after iteration 2400 is: 0.10082323026065662
# Cost after iteration 2450 is: 0.09912649648515058
# Cost after iteration 2500 is: 0.09748350008195467
# Cost after iteration 2550 is: 0.09589177553707516
# Cost after iteration 2600 is: 0.09434900443250428
# Cost after iteration 2650 is: 0.09285300466626357
# Cost after iteration 2700 is: 0.09140172061228995
# Cost after iteration 2750 is: 0.08999321412451093
# Cost after iteration 2800 is: 0.08862565630067724
# Cost after iteration 2850 is: 0.08729731993123321
# Cost after iteration 2900 is: 0.0860065725669618
# Cost after iteration 2950 is: 0.08475187014648977
# Cost after iteration 3000 is: 0.08353175113117936
# Cost after iteration 3050 is: 0.08234483110055923
# Cost after iteration 3100 is: 0.08118979776640213
# Cost after iteration 3150 is: 0.08006540636790739
# Cost after iteration 3200 is: 0.07897047541429308
# Cost after iteration 3250 is: 0.07790388274450091
# Cost after iteration 3300 is: 0.07686456187672586
# Cost after iteration 3350 is: 0.0758514986231594
# Cost after iteration 3400 is: 0.07486372794771293
# Cost after iteration 3450 is: 0.07390033104660312
# Cost after iteration 3500 is: 0.07296043263358017
# Cost after iteration 3550 is: 0.07204319841326622
# Cost after iteration 3600 is: 0.07114783272758801
# Cost after iteration 3650 is: 0.07027357636164917
# Cost after iteration 3700 is: 0.06941970449660617
# Cost after iteration 3750 is: 0.06858552479821142
# Cost after iteration 3800 is: 0.06777037563067975
# Cost after iteration 3850 is: 0.06697362438642307
# Cost after iteration 3900 is: 0.06619466592300854
# Cost after iteration 3950 is: 0.06543292109942286
# Cost after iteration 4000 is: 0.06468783540438967
# Cost after iteration 4050 is: 0.06395887767008063
# Cost after iteration 4100 is: 0.06324553886511142
# Cost after iteration 4150 is: 0.06254733096120184
# Cost after iteration 4200 is: 0.06186378586833424
# Cost after iteration 4250 is: 0.06119445443364945
# Cost after iteration 4300 is: 0.060538905499695685
# Cost after iteration 4350 is: 0.059896725017986985
# Cost after iteration 4400 is: 0.05926751521413419
# Cost after iteration 4450 is: 0.05865089380110214
# Cost after iteration 4500 is: 0.05804649323740325
# Cost after iteration 4550 is: 0.057453960027276464
# Cost after iteration 4600 is: 0.05687295406011967
# Cost after iteration 4650 is: 0.0563031479866455
# Cost after iteration 4700 is: 0.05574422662941117
# Cost after iteration 4750 is: 0.05519588642554599
# Cost after iteration 4800 is: 0.05465783489965324
# Cost after iteration 4850 is: 0.0541297901650077
# Cost after iteration 4900 is: 0.053611480451301555
# Cost after iteration 4950 is: 0.053102643657313285
# Cost after iteration 5000 is: 0.052603026926986346
# Cost after iteration 5050 is: 0.0521123862475077
# Cost after iteration 5100 is: 0.05163048606807289
# Cost after iteration 5150 is: 0.05115709893811203
# Cost after iteration 5200 is: 0.050692005163833
# Cost after iteration 5250 is: 0.05023499248201455
# Cost after iteration 5300 is: 0.04978585575005139
# Cost after iteration 5350 is: 0.04934439665131963
# Cost after iteration 5400 is: 0.04891042341498866
# Cost after iteration 5450 is: 0.04848375054946659
# Cost after iteration 5500 is: 0.04806419858871153
# Cost after iteration 5550 is: 0.047651593850696033
# Cost after iteration 5600 is: 0.047245768207351733
# Cost after iteration 5650 is: 0.04684655886536647
# Cost after iteration 5700 is: 0.046453808157243655
# Cost after iteration 5750 is: 0.04606736334206935
# Cost after iteration 5800 is: 0.045687076415467376
# Cost after iteration 5850 is: 0.045312803928254146
# Cost after iteration 5900 is: 0.04494440681333319
# Cost after iteration 5950 is: 0.04458175022039743
# Cost after iteration 6000 is: 0.04422470335803402
# Cost after iteration 6050 is: 0.04387313934284824
# Cost after iteration 6100 is: 0.043526935055245845
# Cost after iteration 6150 is: 0.0431859710015361
# Cost after iteration 6200 is: 0.04285013118203488
# Cost after iteration 6250 is: 0.042519302964866466
# Cost after iteration 6300 is: 0.04219337696517919
# Cost after iteration 6350 is: 0.04187224692950829
# Cost after iteration 6400 is: 0.04155580962503082
# Cost after iteration 6450 is: 0.04124396473347461
# Cost after iteration 6500 is: 0.040936614749454925
# Cost after iteration 6550 is: 0.040633664883025576
# Cost after iteration 6600 is: 0.04033502296624179
# Cost after iteration 6650 is: 0.04004059936354573
# Cost after iteration 6700 is: 0.03975030688579118
# Cost after iteration 6750 is: 0.03946406070773974
# Cost after iteration 6800 is: 0.03918177828886302
# Cost after iteration 6850 is: 0.03890337929730132
# Cost after iteration 6900 is: 0.03862878553683008
# Cost after iteration 6950 is: 0.03835792087669846
# Cost after iteration 7000 is: 0.038090711184208675
# Cost after iteration 7050 is: 0.03782708425991245
# Cost after iteration 7100 is: 0.037566969775306956
# Cost after iteration 7150 is: 0.03731029921291885
# Cost after iteration 7200 is: 0.03705700580867024
# Cost after iteration 7250 is: 0.036807024496426276
# Cost after iteration 7300 is: 0.03656029185462849
# Cost after iteration 7350 is: 0.03631674605492386
# Cost after iteration 7400 is: 0.03607632681270174
# Cost after iteration 7450 is: 0.035838975339458116
# Cost after iteration 7500 is: 0.0356046342969086
# Cost after iteration 7550 is: 0.03537324775277529
# Cost after iteration 7600 is: 0.03514476113817728
# Cost after iteration 7650 is: 0.03491912120655794
# Cost after iteration 7700 is: 0.03469627599408306
# Cost after iteration 7750 is: 0.03447617478145168
# Cost after iteration 7800 is: 0.03425876805705812
# Cost after iteration 7850 is: 0.03404400748145245
# Cost after iteration 7900 is: 0.03383184585304452
# Cost after iteration 7950 is: 0.03362223707500247
# Cost after iteration 8000 is: 0.03341513612329682
# Cost after iteration 8050 is: 0.033210499015844074
# Cost after iteration 8100 is: 0.03300828278270675
# Cost after iteration 8150 is: 0.03280844543730753
# Cost after iteration 8200 is: 0.03261094594861708
# Cost after iteration 8250 is: 0.032415744214278445
# Cost after iteration 8300 is: 0.03222280103463029
# Cost after iteration 8350 is: 0.032032078087595096
# Cost after iteration 8400 is: 0.031843537904398554
# Cost after iteration 8450 is: 0.03165714384608835
# Cost after iteration 8500 is: 0.03147286008082155
# Cost after iteration 8550 is: 0.0312906515618921
# Cost after iteration 8600 is: 0.03111048400646968
# Cost after iteration 8650 is: 0.030932323875023985
# Cost after iteration 8700 is: 0.030756138351408096
# Cost after iteration 8750 is: 0.030581895323577312
# Cost after iteration 8800 is: 0.030409563364919377
# Cost after iteration 8850 is: 0.03023911171617318
# Cost after iteration 8900 is: 0.030070510267915983
# Cost after iteration 8950 is: 0.02990372954359674
# Cost after iteration 9000 is: 0.029738740683096617
# Cost after iteration 9050 is: 0.0295755154267981
# Cost after iteration 9100 is: 0.029414026100143275
# Cost after iteration 9150 is: 0.029254245598665386
# Cost after iteration 9200 is: 0.029096147373475077
# Cost after iteration 9250 is: 0.02893970541718749
# Cost after iteration 9300 is: 0.028784894250272107
# Cost after iteration 9350 is: 0.028631688907813483
# Cost after iteration 9400 is: 0.028480064926665792
# Cost after iteration 9450 is: 0.028329998332989544
# Cost after iteration 9500 is: 0.028181465630156843
# Cost after iteration 9550 is: 0.028034443787011483
# Cost after iteration 9600 is: 0.027888910226473638
# Cost after iteration 9650 is: 0.027744842814475822
# Cost after iteration 9700 is: 0.027602219849219834
# Cost after iteration 9750 is: 0.02746102005074368
# Cost after iteration 9800 is: 0.02732122255078815
# Cost after iteration 9850 is: 0.027182806882952694
# Cost after iteration 9900 is: 0.027045752973131672
# Cost after iteration 9950 is: 0.026910041130221427
# train accuracy: 97.404120
# test accuracy: 70.000000
